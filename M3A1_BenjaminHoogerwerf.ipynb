# %%
# 7.4
things = ["mozzarella", "cinderella", "salmonella"]

print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
# 7.5
things = ["mozzarella", "Cinderella", "salmonella"]

print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
# When changing "cinderella" to "Cinderella," printing the list variable 'things' reflected the change in capitalization of the first letter.

# %%
# 7.6
things = ["MOZZARELLA", "Cinderella", "salmonella"]

print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
# 7.7
things = ["MOZZARELLA", "Cinderella"]

print("For eradicating Salmonella, you have won the Nobel Peace Prize!")
print(things)
# Out:
# For eradicating Salmonella, you have won the Nobel Peace Prize!
# ['MOZZARELLA', 'Cinderella']

# %%
# 9.1
def good():
    good_kids = ['Harry', 'Ron', 'Hermione']
    print(good_kids)

# %%
# 9.2
def get_odds():
    odd_numbers = []
    for i in range(10):
        if i % 2 == 1:
            odd_numbers.append(i)
    print(odd_numbers[2])

get_odds()
# Out:
# 5
